# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/huangshifeng/Desktop/stage_III_colon_surv/data/raw_data_EDA.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 40 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Patient_ID            144 non-null    int64
#  1   Chart_No              144 non-null    int64
#  2   Dx_Date               144 non-null    object
#  3   Dx_Year               144 non-null    int64
#  4   Age                   144 non-null    int64
#  5   Sex                   144 non-null    int64
#  6   BMI                   140 non-null    float64
#  7   ECOG                  0 non-null      float64
#  8   Tumor_Location        144 non-null    int64
#  9   Tumor_Location_Group  144 non-null    int64
#  10  pT_Stage              144 non-null    object
#  11  pN_Stage              144 non-null    object
#  12  AJCC_Substage         144 non-null    object
#  13  LN_Total              142 non-null    float64
#  14  LN_Positive           142 non-null    float64
#  15  LNR                   142 non-null    float64
#  16  Histology             144 non-null    int64
#  17  Differentiation       49 non-null     float64
#  18  LVI                   108 non-null    float64
#  19  PNI                   107 non-null    float64
#  20  Tumor_Deposits        144 non-null    int64
#  21  Mucinous_Gt_50        144 non-null    int64
#  22  Mucinous_Any          0 non-null      float64
#  23  MSI_Status            29 non-null     object
#  24  Tumor_Size_cm         0 non-null      float64
#  25  CEA_PreOp             114 non-null    float64
#  26  Log_CEA_PreOp         114 non-null    float64
#  27  Radical_Op_Date       144 non-null    object
#  28  Op_Procedure          0 non-null      float64
#  29  PreOp_Albumin         0 non-null      float64
#  30  Last_FU_Date          144 non-null    object
#  31  Unnamed: 31           38 non-null     float64
#  32  edr_18m               144 non-null    int64
#  33  Recurrence            144 non-null    int64
#  34  Recurrence_Date       40 non-null     object
#  35  Recurrence_Type       144 non-null    int64
#  36  Death                 144 non-null    int64
#  37  Death_Cause           144 non-null    object
#  38  DFS_Months            0 non-null      float64
#  39  OS_Months             0 non-null      float64
# dtypes: float64(17), int64(14), object(9)
# memory usage: 45.1+ KB

# %%
selected_cols = ['AJCC_Substage', 'LNR', 'Differentiation', 'PNI', 'edr_18m']
df_ext=df[selected_cols]
df_ext.info()

df_ext.isna().mean()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   AJCC_Substage    144 non-null    object
#  1   LNR              142 non-null    float64
#  2   Differentiation  49 non-null     float64
#  3   PNI              107 non-null    float64
#  4   edr_18m          144 non-null    int64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 5.8+ KB
# AJCC_Substage      0.000000
# LNR                0.013889
# Differentiation    0.659722
# PNI                0.256944
# edr_18m            0.000000
# dtype: float64

# %%
df_ext['AJCC_Substage'].value_counts(dropna=False)
df_ext['AJCC_Substage']=df_ext['AJCC_Substage'].astype('category')
# Out:
# /var/folders/4y/l6fx63p966z4_0myl5b68p8h0000gn/T/ipykernel_95497/1801890503.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ext['AJCC_Substage']=df_ext['AJCC_Substage'].astype('category')

# %%
df_ext['Differentiation'].astype('Int64')
df_ext['PNI'].astype('Int64')
df_ext.to_parquet('EDA_Ext_Val.parquet')
